# %%
import psycopg2
import pandas as pd

# %%
# Connect to Postgres db
try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "f9dLM910&%S%",
                                  host = "dataviz.clw759vfh14c.us-east-2.rds.amazonaws.com",
                                  port = "5432",
                                  database = "my_data_class_db")

    cursor = connection.cursor()
    # Print PostgreSQL Connection properties
    print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
    cursor.execute("SELECT version();")
    record = cursor.fetchone()
    print("You are connected to - ", record,"\n")

except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
# Out:
# {'user': 'postgres', 'dbname': 'my_data_class_db', 'host': 'dataviz.clw759vfh14c.us-east-2.rds.amazonaws.com', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'gssencmode': 'prefer', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# You are connected to -  ('PostgreSQL 11.6 on x86_64-pc-linux-gnu, compiled by gcc (GCC) 4.8.3 20140911 (Red Hat 4.8.3-9), 64-bit',)

# %%
postgreSQL_select_Query = "select * from country where country = 'GBR'"

cursor.execute(postgreSQL_select_Query)
print("Selecting rows from country using cursor.fetchall")
country_sample = cursor.fetchall() 
country_sample
# Out:
# Selecting rows from country using cursor.fetchall
# [('GBR', 'United Kingdom of Great Britain and Northern Ireland (the)', 42526)]

# %%
postgreSQL_select_Query = "select column_name from INFORMATION_SCHEMA.COLUMNS where TABLE_NAME = 'hotel_bookings'"
cursor.execute(postgreSQL_select_Query)
print("Selecting column names using cursor.fetchall")
hb_colnames = cursor.fetchall() 
for col in hb_colnames:
    print(col)
# Out:
# Selecting column names using cursor.fetchall
# ('id',)
# ('hotel',)
# ('is_canceled',)
# ('lead_time',)
# ('arrival_date_year',)
# ('arrival_date_month',)
# ('arrival_date_week_number',)
# ('arrival_date_day_of_month',)
# ('stays_in_weekend_nights',)
# ('stays_in_week_nights',)
# ('adults',)
# ('children',)
# ('babies',)
# ('meal',)
# ('country',)
# ('market_segment',)
# ('distribution_channel',)
# ('is_repeated_guest',)
# ('previous_cancellations',)
# ('previous_bookings_not_canceled',)
# ('reserved_room_type',)
# ('assigned_room_type',)
# ('booking_changes',)
# ('deposit_type',)
# ('agent',)
# ('company',)
# ('days_in_waiting_list',)
# ('customer_type',)
# ('adr',)
# ('required_car_parking_spaces',)
# ('total_of_special_requests',)
# ('reservation_status',)
# ('reservation_status_date',)

# %%
postgreSQL_select_Query = "select * from hotel_bookings where country = 'GBR'"

cursor.execute(postgreSQL_select_Query)
print("Selecting rows from country using cursor.fetchall")
hotel_bookings_sample = cursor.fetchall() 
hotel_bookings_sample_df = pd.DataFrame(hotel_bookings_sample, columns=['id','hotel','is_canceled','lead_time', 'arrival_date_year','arrival_date_month', 'arrival_date_week_number','arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled','reserved_room_type', 'assigned_room_type','booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date'])
# Out:
# Selecting rows from country using cursor.fetchall

# %%
hotel_bookings_sample_df
# Out:
#            id         hotel  is_canceled  lead_time  arrival_date_year  \
# 0           3  Resort Hotel        False          7               2015
# 1           4  Resort Hotel        False         13               2015
# 2           5  Resort Hotel        False         14               2015
# 3           6  Resort Hotel        False         14               2015
# 4          20  Resort Hotel        False          7               2015
# ...       ...           ...          ...        ...                ...
# 12124  119335    City Hotel        False        325               2017
# 12125  119370    City Hotel        False        207               2017
# 12126  119379    City Hotel        False        247               2017
# 12127  119380    City Hotel        False        109               2017
# 12128  119389    City Hotel        False        109               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# 1                   July                        27                          1
# 2                   July                        27                          1
# 3                   July                        27                          1
# 4                   July                        27                          1
# ...                  ...                       ...                        ...
# 12124             August                        35                         30
# 12125             August                        34                         25
# 12126             August                        35                         31
# 12127             August                        35                         31
# 12128             August                        35                         31
#
#        stays_in_weekend_nights  stays_in_week_nights  ...  deposit_type  \
# 0                            0                     1  ...    No Deposit
# 1                            0                     1  ...    No Deposit
# 2                            0                     2  ...    No Deposit
# 3                            0                     2  ...    No Deposit
# 4                            0                     4  ...    No Deposit
# ...                        ...                   ...  ...           ...
# 12124                        0                     4  ...    No Deposit
# 12125                        3                     7  ...    No Deposit
# 12126                        1                     3  ...    No Deposit
# 12127                        1                     3  ...    No Deposit
# 12128                        2                     5  ...    No Deposit
#
#        agent  company days_in_waiting_list customer_type     adr  \
# 0        NaN      NaN                    0     Transient   75.00
# 1      304.0      NaN                    0     Transient   75.00
# 2      240.0      NaN                    0     Transient   98.00
# 3      240.0      NaN                    0     Transient   98.00
# 4      250.0      NaN                    0     Transient  153.00
# ...      ...      ...                  ...           ...     ...
# 12124    9.0      NaN                    0     Transient  129.18
# 12125   14.0      NaN                    0     Transient   96.25
# 12126   42.0      NaN                    0     Transient   86.85
# 12127    9.0      NaN                    0     Transient  155.00
# 12128   89.0      NaN                    0     Transient  104.40
#
#       required_car_parking_spaces  total_of_special_requests  \
# 0                               0                          0
# 1                               0                          0
# 2                               0                          1
# 3                               0                          1
# 4                               0                          1
# ...                           ...                        ...
# 12124                           0                          4
# 12125                           0                          2
# 12126                           0                          0
# 12127                           0                          1
# 12128                           0                          0
#
#        reservation_status  reservation_status_date
# 0               Check-Out               2015-07-02
# 1               Check-Out               2015-07-02
# 2               Check-Out               2015-07-03
# 3               Check-Out               2015-07-03
# 4               Check-Out               2015-07-05
# ...                   ...                      ...
# 12124           Check-Out               2017-09-03
# 12125           Check-Out               2017-09-04
# 12126           Check-Out               2017-09-04
# 12127           Check-Out               2017-09-04
# 12128           Check-Out               2017-09-07
#
# [12129 rows x 33 columns]

# %%
# Close Postgres connection
try:
    connection = psycopg2.connect(user = "postgres",
                                  password = "f9dLM910&%S%",
                                  host = "dataviz.clw759vfh14c.us-east-2.rds.amazonaws.com",
                                  port = "5432",
                                  database = "my_data_class_db")

finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
